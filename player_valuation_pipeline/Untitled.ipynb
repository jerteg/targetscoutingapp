# %%
from valuation.config import load_config
from valuation.pipeline import train_full_pipeline, predict_for_players

# Config laden
config = load_config("configs/default.yaml")

# Training
results = train_full_pipeline(config)

# Predictions
predictions = predict_for_players(config)
# Out:
# [1/10] Load Wyscout data...
#   Current (2025/26): 5527 rows
#   Previous (2024/25): 11579 rows
#
# [2/10] Derive migration-based league multipliers...
#   20 leagues, 373 migraties used
#
# [3/10] Compute category-weighted ratings...
#   6111 player-template combinations
#       Apply migration multipliers...
#
# [4/10] Load TM profiles...
#   92671 spelers
#
# [5/10] Match Wyscout to TM (~2 min)...
# Matching 5,527 vs 92,671...
#   Indexing TM by surname tokens...
#   Index heeft 153,418 unieke surname tokens
#   Grootste bucket: 782 spelers
#     500/5527 (9.0%) — 19s, ETA 189s
#    1000/5527 (18.1%) — 38s, ETA 171s
#    2000/5527 (36.2%) — 72s, ETA 126s
#    2500/5527 (45.2%) — 89s, ETA 108s
#    3000/5527 (54.3%) — 110s, ETA 93s
#    3500/5527 (63.3%) — 131s, ETA 76s
#    4000/5527 (72.4%) — 145s, ETA 55s
#    4500/5527 (81.4%) — 161s, ETA 37s
#    5000/5527 (90.5%) — 178s, ETA 19s
#    5500/5527 (99.5%) — 193s, ETA 1s
#
# ⏱ Total: 194s
#   High-confidence (≥85): 4213 / 5527 (76.2%)
#
# [6/10] Load TM transfer history...
#   21942 paid transfers from 2015+
#
# [7/10] Derive fee-based league multipliers...
#   20 leagues with fee multipliers
#   974 cross-league transfers used
#
# [8/10] Load TM market values...
#   41823 recent values
#
# [9/10] Train market value model...
# Training set: 4613 spelers
# Age curves voor 8 templates
#
# Model performance:
#   Spearman ρ (test): 0.870
#   R² (test):         0.781
#   Median % error:    40.9%
#   Within 50%:        60.0%
#   Within 100%:       85.7%
#
# [10/10] Save all artifacts...
#   Model → C:\Users\Jeroen Tegelaers\Documents\project\player_valuation_pipeline\models\market_value_model.pkl
#   Multipliers → C:\Users\Jeroen Tegelaers\Documents\project\player_valuation_pipeline\models\multipliers.json
#   Predict for all training players...
#   Predictions → C:\Users\Jeroen Tegelaers\Documents\project\player_valuation_pipeline\output\player_predictions.csv
#
# ✓ Pipeline complete. Results in C:\Users\Jeroen Tegelaers\Documents\project\player_valuation_pipeline\output
#   Model: C:\Users\Jeroen Tegelaers\Documents\project\player_valuation_pipeline\models\market_value_model.pkl
#   Metrics: Spearman ρ = 0.870
# [1/5] Load model from C:\Users\Jeroen Tegelaers\Documents\project\player_valuation_pipeline\models\market_value_model.pkl
# [2/5] Load Wyscout: C:/Users/Jeroen Tegelaers/Documents/project/shared/data.csv
# [3/5] Compute ratings with saved multipliers...
# [4/5] Match Wyscout to TM...
# Matching 5,527 vs 92,671...
#   Indexing TM by surname tokens...
#   Index heeft 153,418 unieke surname tokens
#   Grootste bucket: 782 spelers
#     500/5527 (9.0%) — 22s, ETA 225s
